# %% [markdown]
# 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings

# %%
dir(warnings)
# Out:
# ['WarningMessage',
#  '_OptionError',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_add_filter',
#  '_defaultaction',
#  '_filters_mutated',
#  '_formatwarning_orig',
#  '_formatwarnmsg',
#  '_formatwarnmsg_impl',
#  '_getaction',
#  '_getcategory',
#  '_is_internal_frame',
#  '_next_external_frame',
#  '_onceregistry',
#  '_processoptions',
#  '_setoption',
#  '_showwarning_orig',
#  '_showwarnmsg',
#  '_showwarnmsg_impl',
#  '_warn_unawaited_coroutine',
#  'catch_warnings',
#  'defaultaction',
#  'filters',
#  'filterwarnings',
#  'formatwarning',
#  'onceregistry',
#  'resetwarnings',
#  'showwarning',
#  'simplefilter',
#  'sys',
#  'warn',
#  'warn_explicit']

# %% [markdown]
# 2. Load the dataset and display a sample of five rows of the data frame.

# %%
df=pd.read_csv('heart_2020_cleaned.csv')
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# 3. Check the shape of the data (number of rows and columns). Check the general information about the dataframe using the .info() method.

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %% [markdown]
# 4. Check the statistical summary of the dataset and write your inferences.

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# 5. Check the percentage of missing values in each column of the data frame. Drop the missing values if there are any.

# %%
df.isnull().sum()/len(df) * 100

# if find any missing value use
#df.dropna()
# Out:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# PhysicalHealth      0.0
# MentalHealth        0.0
# DiffWalking         0.0
# Sex                 0.0
# AgeCategory         0.0
# Race                0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# KidneyDisease       0.0
# SkinCancer          0.0
# dtype: float64

# %% [markdown]
# 6. Check if there are any duplicate rows. If any drop them and check the shape of the dataframe after dropping duplicates.

# %%
df[df.duplicated()]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2182             No  19.85      No              No     No             0.0
# 3182             No  28.19      No              No     No             0.0
# 3397             No  26.54      No              No     No             0.0
# 3650             No  32.89     Yes              No     No             2.0
# 4061             No  25.84      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319671           No  25.06      No              No     No             0.0
# 319689           No  27.44      No              No     No             0.0
# 319726           No  30.41      No              No     No             0.0
# 319751           No  34.96      No              No     No             0.0
# 319776           No  27.98      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
# find not duplicated valus
df[~df.duplicated()]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
 df.drop_duplicates(keep='first')
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.shape
# Out:
# (319795, 18)

# %% [markdown]
# 7. Check the distribution of the target variable (i.e. 'HeartDisease') and write your observations.

# %%
sns.displot(data=df,x="HeartDisease")

# %% [markdown]
# 8. Visualize the distribution of the target column 'Heart disease' with respect to various categorical features and write your observations.

# %%
 # categorical features
categorical_features = df.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_20968\2484568894.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_features = df.select_dtypes(include=[np.object])
# Index(['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
#        'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity',
#        'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
i=1
plt.figure(figsize=(30,25))
for i,feature in enumerate(categorical_features):
    plt.subplot(6,3,i+1)
    sns.countplot(x=feature,hue='HeartDisease', data=df)
   #i +=1

# %% [markdown]
# 9. Check the unique categories in the column 'Diabetic'. Replace 'Yes (during pregnancy)' as 'Yes' and 'No, borderline diabetes' as 'No'.

# %%
# if change any column value it is temprory changes

df['Diabetic'] = df['Diabetic'].replace({'Yes (during pregnancy)':'Yes', 'No, borderline diabetes':'No'} )

# %%
 df['Diabetic'].value_counts()
# Out:
# No     276434
# Yes     43361
# Name: Diabetic, dtype: int64

# %% [markdown]
# 10. For the target column 'HeartDiease', Replace 'No' as 0 and 'Yes' as 1.

# %%
# if change any column value it is temprory changes

df['HeartDisease'] = df['HeartDisease'].replace({'No':'0','Yes':'1'})

# %%
df['HeartDisease'].value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %% [markdown]
# 11. Label Encode the columns "AgeCategory", "Race", and "GenHealth". Encode the rest of the columns using dummy encoding approach.

# %%
# find categorical columns

df.select_dtypes('object').columns
# Out:
# Index(['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
#        'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity',
#        'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
for col in[ "AgeCategory", "Race", "GenHealth"]:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                 0  16.60     Yes              No     No             3.0
# 1                 0  20.34      No              No    Yes             0.0
# 2                 0  26.58     Yes              No     No            20.0
# 3                 0  24.21      No              No     No             0.0
# 4                 0  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790            1  27.41     Yes              No     No             7.0
# 319791            0  29.84     Yes              No     No             0.0
# 319792            0  24.24      No              No     No             0.0
# 319793            0  32.81      No              No     No             0.0
# 319794            0  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory  Race Diabetic  \
# ...

# %%
# Encode the rest of the columns using dummy encoding approach.
df = pd.get_dummies(df, columns=[ 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
       'Sex', 'Diabetic', 'PhysicalActivity', 'Asthma', 'KidneyDisease',
       'SkinCancer'])

# %%
df
# Out:
#        HeartDisease    BMI  PhysicalHealth  MentalHealth  AgeCategory  Race  \
# 0                 0  16.60             3.0          30.0            7     5
# 1                 0  20.34             0.0           0.0           12     5
# 2                 0  26.58            20.0          30.0            9     5
# 3                 0  24.21             0.0           0.0           11     5
# 4                 0  23.71            28.0           0.0            4     5
# ...             ...    ...             ...           ...          ...   ...
# 319790            1  27.41             7.0           0.0            8     3
# 319791            0  29.84             0.0           0.0            3     3
# 319792            0  24.24             0.0           0.0            5     3
# 319793            0  32.81             0.0           0.0            1     3
# 319794            0  46.56             0.0           0.0           12     3
#
# ...

# %% [markdown]
# 12. Store the target column (i.e.'HeartDisease') in the y variable and the rest of the columns in the X variable.

# %%
x = df.drop(['HeartDisease'],axis=1)
x.sample(5)
y=df['HeartDisease']
y.sample(5)
# Out:
# 220568    0
# 226625    0
# 61768     0
# 29228     0
# 210650    0
# Name: HeartDisease, dtype: object

# %% [markdown]
# 13. Split the dataset into two parts (i.e. 70% train and 30% test) and print the shape of the train and test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %% [markdown]
# 14. Standardize the numerical columns using Standard Scalar approach for both train and test data.

# %%
x_train.head()
# Out:
#           BMI  PhysicalHealth  MentalHealth  AgeCategory  Race  GenHealth  \
# 273582  43.40             2.0           5.0            6     5          2
# 54829   36.85            20.0           0.0           10     5          2
# 1482    35.70            25.0          25.0            6     5          2
# 17407   27.07             5.0          30.0            5     2          4
# 116646  25.02             5.0           0.0            3     1          0
#
#         SleepTime  Smoking_No  Smoking_Yes  AlcoholDrinking_No  ...  \
# 273582        8.0           1            0                   1  ...
# 54829         8.0           0            1                   1  ...
# 1482          5.0           1            0                   1  ...
# 17407         5.0           0            1                   1  ...
# 116646        7.0           1            0                   1  ...
#
#         Diabetic_No  Diabetic_Yes  PhysicalActivity_No  PhysicalActivity_Yes  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardize the numerical columns.(not Standardizing the dummy encoded data)
ss = StandardScaler()
x_train.iloc[:,:7]=ss.fit_transform(x_train.iloc[:,:7])
x_test.iloc[:,:7]=ss.transform(x_test.iloc[:,:7])

# %% [markdown]
# 15. Write a function.
# i) Which can take the model and data as inputs.
# ii) Fits the model with the train data.
# iii) Makes predictions on the test set.
# iv) Returns the Accuracy Score.

# %%
def fit_n_predict(model, x_train, x_test, y_train, y_test):
    
    # fit the model with train data
    model.fit(x_train,y_train)

    #  iii) Makes predictions on the test set.
    pred = model.predict(x_test)

    # calculate the  Accuracy Score.
    accuracy = accuracy_score(y_test, pred)
    return accuracy

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
Lable = 'Logistic Regression'

rs = pd.DataFrame(columns = ['Accuracy'])
rs.loc[Lable] = fit_n_predict(lr,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415

# %% [markdown]
# 16. Use the function and train a Logistic regression, KNN, Naive Bayes, Decision tree, Random Forest, Adaboost, GradientBoost, and Stacked Classifier models and make predictions on test data and evaluate the models, compare and write your conclusions and steps to be taken in future in order to improve the accuracy of the model.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
nb = GaussianNB()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
adb = AdaBoostClassifier()
gb = GradientBoostingClassifier()

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
#Lable = 'nb'


rs.loc['lr'] = fit_n_predict(lr,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
Lable = 'nb'


rs.loc['nb'] = fit_n_predict(nb,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415
# nb                   0.835812

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
# Lable = 'nb'


rs.loc['knn'] = fit_n_predict(knn,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415
# nb                   0.835812
# dt                   0.864685
# gb                   0.916916
# adb                  0.915926
# knn                  0.907785

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
#Lable = 'nb'


rs.loc['dt'] = fit_n_predict(dt,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415
# nb                   0.835812
# dt                   0.864685

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
#Lable = 'nb'


rs.loc['rf'] = fit_n_predict(rf,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# nb                   0.835812
# dt                   0.864508
# rf                   0.905638

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
#Lable = 'nb'


rs.loc['adb'] = fit_n_predict(adb,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415
# nb                   0.835812
# dt                   0.864685
# gb                   0.916916
# adb                  0.915926

# %%
from sklearn.linear_model import LogisticRegression
# Testing the above function
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
#Lable = 'nb'


rs.loc['gb'] = fit_n_predict(gb,x_train,x_test,y_train,y_test)
rs
# Out:
#                      Accuracy
# Logistic Regression  0.915415
# lr                   0.915415
# nb                   0.835812
# dt                   0.864685
# gb                   0.916916
# adb                  0.915926

# %% [markdown]
# Conclusion

# %%
Gradient Boosting algorithm Improve more accuracy of the model.
